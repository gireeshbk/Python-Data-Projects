# %% [markdown]
# ## Step 0: Imports and Reading Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')
pd.set_option('display.max_columns',100)

# %%
df = pd.read_csv(r'C:\Users\Gireesh\Downloads\archive (1)\coaster_db.csv')

# %% [markdown]
# ## Step 1: Data Understanding
# - shape
# - header and tail
# - dtype
# - describe

# %%
df.shape
# Out:
# (1087, 56)

# %%
df.columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
# ...

# %%
df.dtypes
# Out:
# coaster_name                      object
# Length                            object
# Speed                             object
# Location                          object
# Status                            object
# Opening date                      object
# Type                              object
# Manufacturer                      object
# Height restriction                object
# Model                             object
# Height                            object
# Inversions                       float64
# Lift/launch system                object
# Cost                              object
# Trains                            object
# Park section                      object
# Duration                          object
# Capacity                          object
# G-force                           object
# Designer                          object
# Max vertical angle                object
# Drop                              object
# Soft opening date                 object
# ...

# %%
df.describe()
# Out:
#        Inversions  year_introduced    latitude   longitude  speed1_value  \
# count  932.000000      1087.000000  812.000000  812.000000    937.000000
# mean     1.547210      1994.986201   38.373484  -41.595373     53.850374
# std      2.114073        23.475248   15.516596   72.285227     23.385518
# min      0.000000      1884.000000  -48.261700 -123.035700      5.000000
# 25%      0.000000      1989.000000   35.031050  -84.552200     40.000000
# 50%      0.000000      2000.000000   40.289800  -76.653600     50.000000
# 75%      3.000000      2010.000000   44.799600    2.778100     63.000000
# max     14.000000      2022.000000   63.230900  153.426500    240.000000
#
#         speed_mph  height_value   height_ft  Inversions_clean  Gforce_clean
# count  937.000000    965.000000  171.000000       1087.000000    362.000000
# mean    48.617289     89.575171  101.996491          1.326587      3.824006
# std     16.678031    136.246444   67.329092          2.030854      0.989998
# ...

# %% [markdown]
# ## Step 2: Data Preparation
# - Dropping irrelevant columns and rows
# - Identifying duplicates columns
# - Renaming columns
# - Feature creation

# %%
df.drop(['G-force', 'Designer', 'Max vertical angle'], axis=1)
# Out:
#                                 coaster_name                Length  \
# 0                         Switchback Railway        600 ft (180 m)
# 1                          Flip Flap Railway                   NaN
# 2     Switchback Railway (Euclid Beach Park)                   NaN
# 3               Loop the Loop (Coney Island)                   NaN
# 4               Loop the Loop (Young's Pier)                   NaN
# ...                                      ...                   ...
# 1082                 American Dreier Looping    3,444 ft (1,050 m)
# 1083               Pantheon (roller coaster)    3,328 ft (1,014 m)
# 1084               Tron Lightcycle Power Run  3,169.3 ft (966.0 m)
# 1085                                 Tumbili        770 ft (230 m)
# 1086          Wonder Woman Flight of Courage    3,300 ft (1,000 m)
#
#                         Speed                        Location  \
# 0            6 mph (9.7 km/h)                    Coney Island
# ...

# %%
df = df[['coaster_name',
    # 'Length', 'Speed',
    'Location', 'Status',
    # 'Opening date',
    #   'Type',
    'Manufacturer',
#     'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date',
#     'Opened', 
    # 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
       'year_introduced',
        'latitude', 'longitude',
    'Type_Main',
       'opening_date_clean',
    #'speed1', 'speed2', 'speed1_value', 'speed1_unit',
       'speed_mph', 
    #'height_value', 'height_unit',
    'height_ft',
       'Inversions_clean', 'Gforce_clean']].copy()

# %%
df.shape
# Out:
# (1087, 13)

# %%
df.dtypes
# Out:
# coaster_name           object
# Location               object
# Status                 object
# Manufacturer           object
# year_introduced         int64
# latitude              float64
# longitude             float64
# Type_Main              object
# opening_date_clean     object
# speed_mph             float64
# height_ft             float64
# Inversions_clean        int64
# Gforce_clean          float64
# dtype: object

# %%
#change data type
df['opening_date_clean'] = pd.to_datetime(df['opening_date_clean'])

# %%
#Rename columns
df = df.rename(columns={'coaster_name':'Coaster_Name' , 
                        'year_introduced':'Year_Introduced' , 
                        'latitude':'Latitude' , 
                        'longitude':'Longitude', 
                        'opening_date_clean':'Opening_Date' , 
                        'speed_mph':'Speed_Mph' , 
                       'height_ft':'Height_Ft' , 
                       'Inversions_clean':'Inversions' , 
                       'Gforce_clean':'Gforce'})
df.head()
# Out:
#                              Coaster_Name                        Location  \
# 0                      Switchback Railway                    Coney Island
# 1                       Flip Flap Railway                   Sea Lion Park
# 2  Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3            Loop the Loop (Coney Island)                           Other
# 4            Loop the Loop (Young's Pier)                           Other
#
#     Status            Manufacturer  Year_Introduced  Latitude  Longitude  \
# 0  Removed  LaMarcus Adna Thompson             1884   40.5740   -73.9780
# 1  Removed            Lina Beecher             1895   40.5780   -73.9790
# 2   Closed                     NaN             1896   41.5800   -81.5700
# 3  Removed          Edwin Prescott             1901   40.5745   -73.9780
# 4  Removed          Edwin Prescott             1901   39.3538   -74.4342
#
#   Type_Main Opening_Date  Speed_Mph  Height_Ft  Inversions  Gforce
# ...

# %%
#To check for null values
df.isna().sum()
# Out:
# Coaster_Name         0
# Location             0
# Status             213
# Manufacturer        59
# Year_Introduced      0
# Latitude           275
# Longitude          275
# Type_Main            0
# Opening_Date       250
# Speed_Mph          150
# Height_Ft          916
# Inversions           0
# Gforce             725
# dtype: int64

# %%
#To check for duplicated rows
df.loc[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Coaster_Name, Location, Status, Manufacturer, Year_Introduced, Latitude, Longitude, Type_Main, Opening_Date, Speed_Mph, Height_Ft, Inversions, Gforce]
# Index: []

# %%
df.loc[df.duplicated(['Coaster_Name'])]
# Out:
#                             Coaster_Name                   Location  \
# 43                 Crystal Beach Cyclone         Crystal Beach Park
# 60                           Derby Racer               Revere Beach
# 61           Blue Streak (Conneaut Lake)         Conneaut Lake Park
# 167        Big Thunder Mountain Railroad                      Other
# 237    Thunder Run (Canada's Wonderland)        Canada's Wonderland
# ...                                  ...                        ...
# 1063                  Lil' Devil Coaster  Six Flags Great Adventure
# 1064  Little Dipper (Conneaut Lake Park)         Conneaut Lake Park
# 1080                          Iron Gwazi    Busch Gardens Tampa Bay
# 1082             American Dreier Looping                      Other
# 1084           Tron Lightcycle Power Run                      Other
#
#                   Status                                       Manufacturer  \
# ...

# %%
#df.query('Coaster_Name == "Big Thunder Mountain Railroad"')
df=df.loc[~df.duplicated(subset = ['Coaster_Name','Location','Manufacturer','Latitude'])].copy()

# %%
df.reset_index(drop=True)
# Out:
#                                Coaster_Name                        Location  \
# 0                        Switchback Railway                    Coney Island
# 1                         Flip Flap Railway                   Sea Lion Park
# 2    Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3              Loop the Loop (Coney Island)                           Other
# 4              Loop the Loop (Young's Pier)                           Other
# ..                                      ...                             ...
# 985            Ice Breaker (roller coaster)                SeaWorld Orlando
# 986                   Leviathan (Sea World)                       Sea World
# 987               Pantheon (roller coaster)      Busch Gardens Williamsburg
# 988                                 Tumbili                  Kings Dominion
# 989          Wonder Woman Flight of Courage        Six Flags Magic Mountain
#
# ...

# %% [markdown]
# ## Step 3: Feature Understanding
# - Plotting feature distributions
# - To determine potential outliers

# %%
df['Year_Introduced'].value_counts()
# Out:
# Year_Introduced
# 1999    46
# 2000    45
# 1998    30
# 2001    29
# 2002    28
#         ..
# 1956     1
# 1959     1
# 1961     1
# 1895     1
# 1884     1
# Name: count, Length: 101, dtype: int64

# %%
gph1 = df['Year_Introduced'].value_counts().head(10).plot(kind='bar')
gph1.set_title('Top 10 Years of Highest Coasters Introduced')
gph1.set_xlabel('Year Introduced')
gph1.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
gph2 = df['Speed_Mph'].plot(kind='hist',bins=25,title='Top Speed Distribution')
gph2.set_xlabel('Speed')
# Out:
# Text(0.5, 0, 'Speed')

# %%
gph3 = df['Manufacturer'].value_counts().head(10).plot(kind='barh')
gph3.set_xlabel('Count')
plt.show()

# %%
df['Speed_Mph'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# ## Feature Comparison
# - Scatterplot
# - Heatmap Correlation
# - Groupby comparisons

# %%
gph4 = df.plot(kind='scatter', x='Speed_Mph', y='Height_Ft', title='Coaster speed Vs Height')
plt.show()

# %%
#comparing multiple features
gph5 = sns.scatterplot(x='Speed_Mph', y='Height_Ft', data=df, hue='Year_Introduced')
plt.show()

# %%
gph6 = sns.pairplot(df,vars=['Speed_Mph','Height_Ft','Year_Introduced'], hue='Type_Main')
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#Correlations
df_corr = df[['Speed_Mph','Height_Ft','Year_Introduced','Gforce']].dropna().corr()
df_corr
# Out:
#                  Speed_Mph  Height_Ft  Year_Introduced    Gforce
# Speed_Mph         1.000000   0.733999         0.171978  0.607383
# Height_Ft         0.733999   1.000000         0.135413  0.466482
# Year_Introduced   0.171978   0.135413         1.000000  0.160247
# Gforce            0.607383   0.466482         0.160247  1.000000

# %%
sns.heatmap(df_corr, annot=True)
plt.show()

# %% [markdown]
# ## Step 5: Ask a question about data
#
# What are the locations with fastest Coasters with having minimum of 10 coasters

# %%
#df['Location'].value_counts()
gph7 = df.query('Location != "Other"').groupby('Location')['Speed_Mph'] \
.agg(['mean','count']) \
.query('count >=10') \
.sort_values('mean')['mean'] \
.plot(kind='barh', title='Average Speed by Location',figsize=(10,5))

gph7.set_xlabel('Avergae Coaster Speed')
plt.show()
